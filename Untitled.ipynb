# %%
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt

import segmentation as s
import importlib

from math import atan2, sqrt, sin, cos, pi

matplotlib.rcParams['figure.figsize'] = 8,6

# %%
importlib.reload(s)
ii = cv2.imread('images/ISIC_0024732.jpg')
ii = cv2.cvtColor(ii, cv2.COLOR_BGR2RGB)
oot_contour = s.segment(ii)
plt.figure()
plt.imshow(ii)

cv2.drawContours(ii, [oot_contour], -1, (0, 255, 0), 2)
plt.figure()
plt.imshow(ii, 'gray')
# Out:
# uint8
